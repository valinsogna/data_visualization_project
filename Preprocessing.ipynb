# %%
import pandas as pd
import numpy

# %%
performances = pd.read_csv("performances.csv")
aspects = pd.read_csv("judged-aspects.csv")
scores = pd.read_csv("judge-scores.csv")
judges = pd.read_csv("judges.csv")

# %%
performances.head()
# Out:
#   performance_id                              competition  \
# 0     6e4bd41ac5  Grand Prix Final 2017 Senior and Junior
# 1     562c01c5a6  Grand Prix Final 2017 Senior and Junior
# 2     2de894c029  Grand Prix Final 2017 Senior and Junior
# 3     06e4b8b67e  Grand Prix Final 2017 Senior and Junior
# 4     72e3228deb  Grand Prix Final 2017 Senior and Junior
#
#                 program                               name nation  rank  \
# 0  ICE DANCE FREE DANCE     Anna CAPPELLINI / Luca LANOTTE    ITA     5
# 1  ICE DANCE FREE DANCE  Madison HUBBELL / Zachary DONOHUE    USA     4
# 2  ICE DANCE FREE DANCE         Madison CHOCK / Evan BATES    USA     3
# 3  ICE DANCE FREE DANCE    Maia SHIBUTANI / Alex SHIBUTANI    USA     6
# 4  ICE DANCE FREE DANCE          Tessa VIRTUE / Scott MOIR    CAN     2
#
#    starting_number  total_segment_score  total_element_score  \
# 0                1               110.99                56.01
# 1                2               112.59                57.42
# 2                3               112.79                57.25
# 3                4               109.91                54.15
# 4                5               118.33                59.66
#
#    total_component_score  total_deductions
# 0                  54.98               0.0
# 1                  55.17               0.0
# 2                  55.54               0.0
# 3                  55.76               0.0
# 4                  58.67               0.0

# %%
# rinomino le colonne per evitare incomprensioni dopo le join
performances.rename(columns={'name': 'athlete_name',
                             'nation': 'athlete_nation'}, inplace=True)

# %%
# verifico la presenza di NA
performances.isnull().sum(axis = 0)
# Out:
# performance_id           0
# competition              0
# program                  0
# athlete_name             0
# athlete_nation           0
# rank                     0
# starting_number          0
# total_segment_score      0
# total_element_score      0
# total_component_score    0
# total_deductions         0
# dtype: int64

# %%
# se le seguenti colonne dovessero servire per rispondere a delle domande, non runnare questa cella
# - starting_number

performances.drop('starting_number', axis=1, inplace=True)
#performances.drop('total_segment_score', axis=1, inplace=True)
#performances.drop('total_element_score', axis=1, inplace=True)
#performances.drop('total_component_score', axis=1, inplace=True)

# %%
aspects.head(6)
# Out:
#     aspect_id performance_id     section  aspect_num  aspect_desc info_flag  \
# 0  00034b9414     b639d77459  components         NaN  Transitions       NaN
# 1  0004dd08d6     9589bb2ebf  components         NaN  Transitions       NaN
# 2  000b8b5070     71d2b1b597  components         NaN  Performance       NaN
# 3  000cec97c9     41a2345881  components         NaN  Transitions       NaN
# 4  000df5399a     b017147b2f    elements         1.0         3Tw2       NaN
# 5  000f259b7c     a4a69ced64    elements         2.0        CoSp4       NaN
#
#   credit_flag  base_value  factor   goe  ref  scores_of_panel
# 0         NaN         NaN     0.8   NaN  NaN             9.07
# 1         NaN         NaN     0.8   NaN  NaN             6.64
# 2         NaN         NaN     1.0   NaN  NaN             7.68
# 3         NaN         NaN     0.8   NaN  NaN             4.71
# 4         NaN         5.8     NaN -0.20  NaN             5.60
# 5         NaN         5.6     NaN  0.77  NaN             6.37

# %%
# rinomino le colonne per evitare incomprensioni dopo le join
aspects.rename(columns={'scores_of_panel': 'aspect_final_score'}, inplace=True)

# %%
# verifico la presenza di NA
print(aspects.isnull().sum(axis = 0))

# elimino le colonne con NA che non mi servono
# - aspect_num      8630 NA (the positional order of the aspect within the performance and section)
# - info_flag
# - credit_flag
# - base_value      8630 NA
# - goe             8630 NA
# - ref
# - factor

# Sospetto che le 8630 NA ci siano per i components.
# Controllo:
print(aspects['section'].value_counts()['components']) #8630 infatti!
print(aspects[aspects["section"] == 'components'].head())

#aspects.drop('aspect_num', axis=1, inplace=True)
aspects.drop('info_flag', axis=1, inplace=True)
aspects.drop('credit_flag', axis=1, inplace=True)
#aspects.drop('base_value', axis=1, inplace=True)
aspects.drop('goe', axis=1, inplace=True)
aspects.drop('ref', axis=1, inplace=True)
aspects.drop('factor', axis=1, inplace=True)
# Out:
# aspect_id                 0
# performance_id            0
# section                   0
# aspect_num             8630
# aspect_desc               0
# info_flag             22937
# credit_flag           21204
# base_value             8630
# factor                15302
# goe                    8630
# ref                   23932
# aspect_final_score        0
# dtype: int64
# 8630
#     aspect_id performance_id     section  aspect_num  aspect_desc info_flag  \
# 0  00034b9414     b639d77459  components         NaN  Transitions       NaN
# 1  0004dd08d6     9589bb2ebf  components         NaN  Transitions       NaN
# 2  000b8b5070     71d2b1b597  components         NaN  Performance       NaN
# 3  000cec97c9     41a2345881  components         NaN  Transitions       NaN
# 6  001282e1b1     012b24851b  components         NaN  Performance       NaN
#
#   credit_flag  base_value  factor  goe  ref  aspect_final_score
# 0         NaN         NaN     0.8  NaN  NaN                9.07
# 1         NaN         NaN     0.8  NaN  NaN                6.64
# 2         NaN         NaN     1.0  NaN  NaN                7.68
# 3         NaN         NaN     0.8  NaN  NaN                4.71
# 6         NaN         NaN     2.0  NaN  NaN                6.82

# %%
# rinomino le colonne per evitare incomprensioni dopo le join

# ATT: goe (-3,+3) is translated by base_value to the actual number of points awarded for that element
aspects.rename(columns={'base_value': 'element_base_value',
                        'aspect_num': 'element_order'}, inplace=True)

# %%
scores.head(1)
# Out:
#     aspect_id judge  score
# 0  00034b9414    J1    9.0

# %%
# rinomino le colonne per evitare incomprensioni dopo le join
scores.rename(columns={'score': 'judge_score'}, inplace=True) #GOE (for elements) and score (for components)!!!!

# %%
# verifico la presenza di NA
scores.isnull().sum(axis = 0)
# Out:
# aspect_id      0
# judge          0
# judge_score    0
# dtype: int64

# %%
judges.head(1)
# Out:
#         judge_name assigned_country        role      segment_category  \
# 0  Ms. Chihee RHEE              KOR  Judge No.1  Free Dance|Ice Dance
#
#                   pdf_name               program  \
# 0  4f3031488c_data0405.pdf  ICE DANCE FREE DANCE
#
#                                competition  \
# 0  Grand Prix Final 2017 Senior and Junior
#
#                                 officials_table_link  \
# 0  http://www.isuresults.com/results/season1718/g...
#
#                                     results_pdf_link clean_judge_name
# 0  http://www.isuresults.com/results/season1718/g...      Chihee RHEE

# %%
# rinomino le colonne per evitare incomprensioni dopo le join
judges.rename(columns={'judge_name': 'del_judge_name',
                       'clean_judge_name': 'judge_name',
                       'assigned_country': 'judge_nation'}, inplace=True)

# %%
# elimino le colonne inutili
judges.drop('segment_category', axis=1, inplace=True)
judges.drop('pdf_name', axis=1, inplace=True)
judges.drop('officials_table_link', axis=1, inplace=True)
judges.drop('results_pdf_link', axis=1, inplace=True)
judges.drop('del_judge_name', axis=1, inplace=True)

# %%
scores['judge'].value_counts()
# Out:
# J1    23843
# J2    23843
# J3    23843
# J4    23843
# J5    23843
# J7    23843
# J8    23843
# J9    23843
# J6    23787
# Name: judge, dtype: int64

# %%
judges['role'].value_counts()
# Out:
# Judge No.1    152
# Judge No.2    152
# Judge No.3    152
# Judge No.4    152
# Judge No.5    152
# Judge No.6    152
# Judge No.7    152
# Judge No.8    152
# Judge No.9    152
# Name: role, dtype: int64

# %%
# uniformo i nomi dei giudici
judges.loc[judges["role"] == "Judge No.1", "role"] = "J1"
judges.loc[judges["role"] == "Judge No.2", "role"] = "J2"
judges.loc[judges["role"] == "Judge No.3", "role"] = "J3"
judges.loc[judges["role"] == "Judge No.4", "role"] = "J4"
judges.loc[judges["role"] == "Judge No.5", "role"] = "J5"
judges.loc[judges["role"] == "Judge No.6", "role"] = "J6"
judges.loc[judges["role"] == "Judge No.7", "role"] = "J7"
judges.loc[judges["role"] == "Judge No.8", "role"] = "J8"
judges.loc[judges["role"] == "Judge No.9", "role"] = "J9"

# %%
# creo il df facendo una inner join tra aspects e performances:
print("performances.shape:",performances.shape)
print("aspects.shape:",aspects.shape)
df = aspects.merge(performances,
                   how='inner',
                   on='performance_id')
# Out:
# performances.shape: (1726, 10)
# aspects.shape: (23932, 7)

# %%
# aggiungo tutta la tabella scores
print("df.shape:",df.shape)
print("scores.shape:",scores.shape)
df = df.merge(scores,
              how='inner',
              on='aspect_id')
# Out:
# df.shape: (23932, 16)
# scores.shape: (214531, 3)

# %%
print("df.shape:",df.shape)
# Out:
# df.shape: (214531, 18)

# %%
# aggiungo nomi e nazionalità dei giudici
print("df.shape:",df.shape)
print("judges.shape:",judges.shape)
df = df.merge(judges,
              how='inner',
              left_on=['competition','program','judge'],
              right_on=['competition','program','role'])
# Out:
# df.shape: (214531, 18)
# judges.shape: (1368, 5)

# %%
print("df.shape:",df.shape)
# Out:
# df.shape: (214531, 21)

# %%
df.head(1)
# Out:
#     aspect_id performance_id     section  element_order  aspect_desc  \
# 0  00034b9414     b639d77459  components            NaN  Transitions
#
#    element_base_value  aspect_final_score  \
# 0                 NaN                9.07
#
#                                       competition               program  \
# 0  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
#
#         athlete_name  ... rank  total_segment_score  total_element_score  \
# 0  Evgenia MEDVEDEVA  ...    1                78.92                 42.0
#
#    total_component_score  total_deductions  judge judge_score  judge_nation  \
# 0                  36.92               0.0     J1         9.0           ISU
#
#   role   judge_name
# 0   J1  Agita ABELE
#
# [1 rows x 21 columns]

# %%
# elimino le colonne non più necessarie
df.drop('judge', axis=1, inplace=True)
df.drop('role', axis=1, inplace=True)

# %%
df.head(1)
# Out:
#     aspect_id performance_id     section  element_order  aspect_desc  \
# 0  00034b9414     b639d77459  components            NaN  Transitions
#
#    element_base_value  aspect_final_score  \
# 0                 NaN                9.07
#
#                                       competition               program  \
# 0  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
#
#         athlete_name athlete_nation  rank  total_segment_score  \
# 0  Evgenia MEDVEDEVA            RUS     1                78.92
#
#    total_element_score  total_component_score  total_deductions  judge_score  \
# 0                 42.0                  36.92               0.0          9.0
#
#   judge_nation   judge_name
# 0          ISU  Agita ABELE

# %%
# riordino le colonne in modo sensato
df = df[['competition',
         'program',
         'performance_id',
         'athlete_name',
         'athlete_nation',
         'rank',
         'total_segment_score',
         'total_element_score',
         'total_component_score',
         'total_deductions',
         'aspect_id',
         'aspect_desc',
         'element_order',
         'element_base_value',
         'section',
         'aspect_final_score',
         'judge_name',
         'judge_nation',
         'judge_score'
        ]]

# %%
df.head(50)
# Out:
#                                        competition               program  \
# 0   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 1   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 2   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 3   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 4   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 5   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 6   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 7   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 8   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 9   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 10  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 11  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 12  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 13  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 14  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 15  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 16  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 17  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 18  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 19  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 20  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 21  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 22  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 23  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 24  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 25  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 26  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 27  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 28  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 29  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 30  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 31  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 32  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 33  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 34  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 35  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 36  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 37  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 38  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 39  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 40  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 41  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 42  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 43  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 44  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 45  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 46  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 47  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 48  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 49  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
#
#    performance_id       athlete_name athlete_nation  rank  \
# 0      b639d77459  Evgenia MEDVEDEVA            RUS     1
# 1      b639d77459  Evgenia MEDVEDEVA            RUS     1
# 2      b639d77459  Evgenia MEDVEDEVA            RUS     1
# 3      b639d77459  Evgenia MEDVEDEVA            RUS     1
# 4      b639d77459  Evgenia MEDVEDEVA            RUS     1
# 5      b639d77459  Evgenia MEDVEDEVA            RUS     1
# 6      b639d77459  Evgenia MEDVEDEVA            RUS     1
# 7      b639d77459  Evgenia MEDVEDEVA            RUS     1
# 8      b639d77459  Evgenia MEDVEDEVA            RUS     1
# 9      b639d77459  Evgenia MEDVEDEVA            RUS     1
# 10     b639d77459  Evgenia MEDVEDEVA            RUS     1
# 11     b639d77459  Evgenia MEDVEDEVA            RUS     1
# 12     4764e4873e      Natasha MCKAY            GBR    24
# 13     4764e4873e      Natasha MCKAY            GBR    24
# 14     4764e4873e      Natasha MCKAY            GBR    24
# 15     4764e4873e      Natasha MCKAY            GBR    24
# 16     4764e4873e      Natasha MCKAY            GBR    24
# 17     4764e4873e      Natasha MCKAY            GBR    24
# 18     4764e4873e      Natasha MCKAY            GBR    24
# 19     4764e4873e      Natasha MCKAY            GBR    24
# 20     4764e4873e      Natasha MCKAY            GBR    24
# 21     4764e4873e      Natasha MCKAY            GBR    24
# 22     4764e4873e      Natasha MCKAY            GBR    24
# 23     4764e4873e      Natasha MCKAY            GBR    24
# 24     877e5c34bb    Anna POGORILAYA            RUS     2
# 25     877e5c34bb    Anna POGORILAYA            RUS     2
# 26     877e5c34bb    Anna POGORILAYA            RUS     2
# 27     877e5c34bb    Anna POGORILAYA            RUS     2
# 28     877e5c34bb    Anna POGORILAYA            RUS     2
# 29     877e5c34bb    Anna POGORILAYA            RUS     2
# 30     877e5c34bb    Anna POGORILAYA            RUS     2
# 31     877e5c34bb    Anna POGORILAYA            RUS     2
# 32     877e5c34bb    Anna POGORILAYA            RUS     2
# 33     877e5c34bb    Anna POGORILAYA            RUS     2
# 34     877e5c34bb    Anna POGORILAYA            RUS     2
# 35     877e5c34bb    Anna POGORILAYA            RUS     2
# 36     53868b204a      Kerstin FRANK            AUT    17
# 37     53868b204a      Kerstin FRANK            AUT    17
# 38     53868b204a      Kerstin FRANK            AUT    17
# 39     53868b204a      Kerstin FRANK            AUT    17
# 40     53868b204a      Kerstin FRANK            AUT    17
# 41     53868b204a      Kerstin FRANK            AUT    17
# 42     53868b204a      Kerstin FRANK            AUT    17
# 43     53868b204a      Kerstin FRANK            AUT    17
# 44     53868b204a      Kerstin FRANK            AUT    17
# 45     53868b204a      Kerstin FRANK            AUT    17
# 46     53868b204a      Kerstin FRANK            AUT    17
# 47     53868b204a      Kerstin FRANK            AUT    17
# 48     da4b091d04   Carolina KOSTNER            ITA     3
# 49     da4b091d04   Carolina KOSTNER            ITA     3
#
#     total_segment_score  total_element_score  total_component_score  \
# 0                 78.92                42.00                  36.92
# 1                 78.92                42.00                  36.92
# 2                 78.92                42.00                  36.92
# 3                 78.92                42.00                  36.92
# 4                 78.92                42.00                  36.92
# 5                 78.92                42.00                  36.92
# 6                 78.92                42.00                  36.92
# 7                 78.92                42.00                  36.92
# 8                 78.92                42.00                  36.92
# 9                 78.92                42.00                  36.92
# 10                78.92                42.00                  36.92
# 11                78.92                42.00                  36.92
# 12                45.97                24.77                  21.20
# 13                45.97                24.77                  21.20
# 14                45.97                24.77                  21.20
# 15                45.97                24.77                  21.20
# 16                45.97                24.77                  21.20
# 17                45.97                24.77                  21.20
# 18                45.97                24.77                  21.20
# 19                45.97                24.77                  21.20
# 20                45.97                24.77                  21.20
# 21                45.97                24.77                  21.20
# 22                45.97                24.77                  21.20
# 23                45.97                24.77                  21.20
# 24                74.39                39.90                  34.49
# 25                74.39                39.90                  34.49
# 26                74.39                39.90                  34.49
# 27                74.39                39.90                  34.49
# 28                74.39                39.90                  34.49
# 29                74.39                39.90                  34.49
# 30                74.39                39.90                  34.49
# 31                74.39                39.90                  34.49
# 32                74.39                39.90                  34.49
# 33                74.39                39.90                  34.49
# 34                74.39                39.90                  34.49
# 35                74.39                39.90                  34.49
# 36                51.47                29.04                  22.43
# 37                51.47                29.04                  22.43
# 38                51.47                29.04                  22.43
# 39                51.47                29.04                  22.43
# 40                51.47                29.04                  22.43
# 41                51.47                29.04                  22.43
# 42                51.47                29.04                  22.43
# 43                51.47                29.04                  22.43
# 44                51.47                29.04                  22.43
# 45                51.47                29.04                  22.43
# 46                51.47                29.04                  22.43
# 47                51.47                29.04                  22.43
# 48                72.40                36.80                  35.60
# 49                72.40                36.80                  35.60
#
#     total_deductions   aspect_id                  aspect_desc  element_order  \
# 0                0.0  00034b9414                  Transitions            NaN
# 1                0.0  0127af74a7               Skating Skills            NaN
# 2                0.0  38bda018f5                          3Lo            4.0
# 3                0.0  50366b5d60                        3F+3T            3.0
# 4                0.0  6e36e62b05                       CCoSp4            6.0
# 5                0.0  8f7180d180                           2A            5.0
# 6                0.0  9158f70d60                  Composition            NaN
# 7                0.0  9d6f320ec5  Interpretation of the Music            NaN
# 8                0.0  a85b51a8e7                  Performance            NaN
# 9                0.0  c07f5eb3da                        FCSp4            1.0
# 10               0.0  c470fc1115                         LSp4            7.0
# 11               0.0  f3446fba3f                        StSq4            2.0
# 12               0.0  002472182a                        FSSp4            7.0
# 13               0.0  06cd6d1696  Interpretation of the Music            NaN
# 14               0.0  0a85228215                        StSq3            6.0
# 15               0.0  190fbefa7e                           2A            3.0
# 16               0.0  1fac54c76e                  Performance            NaN
# 17               0.0  3a9f3c8e88               Skating Skills            NaN
# 18               0.0  4fe8aea380                  Composition            NaN
# 19               0.0  5e6e1022e4                       3Lo+2T            1.0
# 20               0.0  6c94dcbb68                         CSp3            4.0
# 21               0.0  76e48de619                       CCoSp3            5.0
# 22               0.0  a195144536                          3S<            2.0
# 23               0.0  a74f3add32                  Transitions            NaN
# 24               0.0  01bd47859b                          3Lo            4.0
# 25               0.0  123e30211e                  Composition            NaN
# 26               0.0  273d80fc13                           2A            5.0
# 27               0.0  42462a01eb               Skating Skills            NaN
# 28               0.0  6ce010991d                       3Lz+3T            1.0
# 29               0.0  87257a19fa                       CCoSp4            2.0
# 30               0.0  90a554ff3c  Interpretation of the Music            NaN
# 31               0.0  ac3d87748e                  Performance            NaN
# 32               0.0  b11b5cae6d                        FCSp4            3.0
# 33               0.0  e1f98bd09b                  Transitions            NaN
# 34               0.0  e48e689678                        StSq4            6.0
# 35               0.0  f716565ca9                         LSp4            7.0
# 36               0.0  01cfdd01de                       CCoSp4            7.0
# 37               0.0  0d5c9cf486                         LSp4            5.0
# 38               0.0  34be6ef298                        3T+2T            1.0
# 39               0.0  48fb57cc3c                  Transitions            NaN
# 40               0.0  760692144c                           3S            4.0
# 41               0.0  96ccffd2c0  Interpretation of the Music            NaN
# 42               0.0  ad01320db2                  Performance            NaN
# 43               0.0  c18c1c70e2                        StSq3            3.0
# 44               0.0  d2c785939a                        FCSp4            2.0
# 45               0.0  e06dd3ed7b                           2A            6.0
# 46               0.0  ed8f495eb6                  Composition            NaN
# 47               0.0  fa6344aea5               Skating Skills            NaN
# 48               0.0  01e4a91010               Skating Skills            NaN
# 49               0.0  087cbb2685                           2A            4.0
#
#     element_base_value     section  aspect_final_score   judge_name  \
# 0                  NaN  components                9.07  Agita ABELE
# 1                  NaN  components                9.14  Agita ABELE
# 2                 5.61    elements                7.21  Agita ABELE
# 3                10.56    elements               12.16  Agita ABELE
# 4                 3.50    elements                4.50  Agita ABELE
# 5                 3.63    elements                4.63  Agita ABELE
# 6                  NaN  components                9.21  Agita ABELE
# 7                  NaN  components                9.36  Agita ABELE
# 8                  NaN  components                9.36  Agita ABELE
# 9                 3.20    elements                4.20  Agita ABELE
# 10                2.70    elements                3.70  Agita ABELE
# 11                3.90    elements                5.60  Agita ABELE
# 12                3.00    elements                3.21  Agita ABELE
# 13                 NaN  components                5.54  Agita ABELE
# 14                3.30    elements                3.80  Agita ABELE
# 15                3.30    elements                2.73  Agita ABELE
# 16                 NaN  components                5.50  Agita ABELE
# 17                 NaN  components                5.21  Agita ABELE
# 18                 NaN  components                5.25  Agita ABELE
# 19                6.40    elements                7.00  Agita ABELE
# 20                2.30    elements                2.37  Agita ABELE
# 21                3.00    elements                3.36  Agita ABELE
# 22                3.10    elements                2.30  Agita ABELE
# 23                 NaN  components                5.00  Agita ABELE
# 24                5.61    elements                6.41  Agita ABELE
# 25                 NaN  components                8.54  Agita ABELE
# 26                3.63    elements                4.20  Agita ABELE
# 27                 NaN  components                8.61  Agita ABELE
# 28               10.30    elements               11.70  Agita ABELE
# 29                3.50    elements                4.36  Agita ABELE
# 30                 NaN  components                8.75  Agita ABELE
# 31                 NaN  components                8.79  Agita ABELE
# 32                3.20    elements                4.13  Agita ABELE
# 33                 NaN  components                8.43  Agita ABELE
# 34                3.90    elements                5.40  Agita ABELE
# 35                2.70    elements                3.70  Agita ABELE
# 36                3.50    elements                4.00  Agita ABELE
# 37                2.70    elements                2.70  Agita ABELE
# 38                5.60    elements                6.50  Agita ABELE
# 39                 NaN  components                5.21  Agita ABELE
# 40                4.84    elements                5.14  Agita ABELE
# 41                 NaN  components                5.57  Agita ABELE
# 42                 NaN  components                5.79  Agita ABELE
# 43                3.30    elements                3.37  Agita ABELE
# 44                3.20    elements                3.27  Agita ABELE
# 45                3.63    elements                4.06  Agita ABELE
# 46                 NaN  components                5.57  Agita ABELE
# 47                 NaN  components                5.89  Agita ABELE
# 48                 NaN  components                8.89  Agita ABELE
# 49                3.63    elements                4.27  Agita ABELE
#
#    judge_nation  judge_score
# 0           ISU         9.00
# 1           ISU         9.25
# 2           ISU         3.00
# 3           ISU         3.00
# 4           ISU         2.00
# 5           ISU         2.00
# 6           ISU         9.25
# 7           ISU         9.50
# 8           ISU         9.50
# 9           ISU         2.00
# 10          ISU         2.00
# 11          ISU         3.00
# 12          ISU         0.00
# 13          ISU         5.25
# 14          ISU         1.00
# 15          ISU        -2.00
# 16          ISU         5.25
# 17          ISU         5.00
# 18          ISU         5.00
# 19          ISU         1.00
# 20          ISU         1.00
# 21          ISU         1.00
# 22          ISU        -2.00
# 23          ISU         4.75
# 24          ISU         1.00
# 25          ISU         8.75
# 26          ISU         2.00
# 27          ISU         9.00
# 28          ISU         2.00
# 29          ISU         2.00
# 30          ISU         9.25
# 31          ISU         9.00
# 32          ISU         2.00
# 33          ISU         8.50
# 34          ISU         3.00
# 35          ISU         1.00
# 36          ISU         1.00
# 37          ISU         0.00
# 38          ISU         2.00
# 39          ISU         5.75
# 40          ISU         1.00
# 41          ISU         6.25
# 42          ISU         6.50
# 43          ISU         1.00
# 44          ISU         1.00
# 45          ISU         1.00
# 46          ISU         6.25
# 47          ISU         6.25
# 48          ISU         9.25
# 49          ISU         1.00

# %%
df.to_csv('final',index=False)
