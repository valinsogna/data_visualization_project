# %%
import pandas as pd
import numpy

# %%
performances = pd.read_csv("performances.csv")
aspects = pd.read_csv("judged-aspects.csv")
scores = pd.read_csv("judge-scores.csv")
judges = pd.read_csv("judges.csv")

# %%
performances.head(1)
# Out:
#   performance_id                              competition  \
# 0     6e4bd41ac5  Grand Prix Final 2017 Senior and Junior
#
#                 program                            name nation  rank  \
# 0  ICE DANCE FREE DANCE  Anna CAPPELLINI / Luca LANOTTE    ITA     5
#
#    starting_number  total_segment_score  total_element_score  \
# 0                1               110.99                56.01
#
#    total_component_score  total_deductions
# 0                  54.98               0.0

# %%
# rinomino le colonne per evitare incomprensioni dopo le join
performances.rename(columns={'name': 'athlete_name',
                             'nation': 'athlete_nation'}, inplace=True)

# %%
# verifico la presenza di NA
performances.isnull().sum(axis = 0)
# Out:
# performance_id           0
# competition              0
# program                  0
# athlete_name             0
# athlete_nation           0
# rank                     0
# starting_number          0
# total_segment_score      0
# total_element_score      0
# total_component_score    0
# total_deductions         0
# dtype: int64

# %%
# se le seguenti colonne dovessero servire per rispondere a delle domande, non runnare questa cella
# - starting_number
# - total_segment_score
# - total_element_score
# - total_component_score
performances.drop('starting_number', axis=1, inplace=True)
performances.drop('total_segment_score', axis=1, inplace=True)
performances.drop('total_element_score', axis=1, inplace=True)
performances.drop('total_component_score', axis=1, inplace=True)

# %%
aspects.head(1)
# Out:
#     aspect_id performance_id     section  aspect_num  aspect_desc info_flag  \
# 0  00034b9414     b639d77459  components         NaN  Transitions       NaN
#
#   credit_flag  base_value  factor  goe  ref  scores_of_panel
# 0         NaN         NaN     0.8  NaN  NaN             9.07

# %%
# rinomino le colonne per evitare incomprensioni dopo le join
aspects.rename(columns={'scores_of_panel': 'aspect_final_score'}, inplace=True)

# %%
# verifico la presenza di NA
aspects.isnull().sum(axis = 0)

# elimino le colonne con NA che non mi servono
# - aspect_num
# - info_flag
# - credit_flag
# - base_value
# - goe
# - ref
# - factor

aspects.drop('aspect_num', axis=1, inplace=True)
aspects.drop('info_flag', axis=1, inplace=True)
aspects.drop('credit_flag', axis=1, inplace=True)
aspects.drop('base_value', axis=1, inplace=True)
aspects.drop('goe', axis=1, inplace=True)
aspects.drop('ref', axis=1, inplace=True)
aspects.drop('factor', axis=1, inplace=True)

# %%
scores.head(1)
# Out:
#     aspect_id judge  score
# 0  00034b9414    J1    9.0

# %%
# rinomino le colonne per evitare incomprensioni dopo le join
scores.rename(columns={'score': 'judge_score'}, inplace=True)

# %%
# verifico la presenza di NA
scores.isnull().sum(axis = 0)
# Out:
# aspect_id      0
# judge          0
# judge_score    0
# dtype: int64

# %%
judges.head(1)
# Out:
#         judge_name assigned_country        role      segment_category  \
# 0  Ms. Chihee RHEE              KOR  Judge No.1  Free Dance|Ice Dance
#
#                   pdf_name               program  \
# 0  4f3031488c_data0405.pdf  ICE DANCE FREE DANCE
#
#                                competition  \
# 0  Grand Prix Final 2017 Senior and Junior
#
#                                 officials_table_link  \
# 0  http://www.isuresults.com/results/season1718/g...
#
#                                     results_pdf_link clean_judge_name
# 0  http://www.isuresults.com/results/season1718/g...      Chihee RHEE

# %%
# rinomino le colonne per evitare incomprensioni dopo le join
judges.rename(columns={'judge_name': 'del_judge_name',
                       'clean_judge_name': 'judge_name',
                       'assigned_country': 'judge_nation'}, inplace=True)

# %%
# elimino le colonne inutili
judges.drop('segment_category', axis=1, inplace=True)
judges.drop('pdf_name', axis=1, inplace=True)
judges.drop('officials_table_link', axis=1, inplace=True)
judges.drop('results_pdf_link', axis=1, inplace=True)
judges.drop('del_judge_name', axis=1, inplace=True)

# %%
scores['judge'].value_counts()
# Out:
# J1    23843
# J2    23843
# J3    23843
# J4    23843
# J5    23843
# J7    23843
# J8    23843
# J9    23843
# J6    23787
# Name: judge, dtype: int64

# %%
judges['role'].value_counts()
# Out:
# Judge No.1    152
# Judge No.2    152
# Judge No.3    152
# Judge No.4    152
# Judge No.5    152
# Judge No.6    152
# Judge No.7    152
# Judge No.8    152
# Judge No.9    152
# Name: role, dtype: int64

# %%
# uniformo i nomi dei giudici
judges.loc[judges["role"] == "Judge No.1", "role"] = "J1"
judges.loc[judges["role"] == "Judge No.2", "role"] = "J2"
judges.loc[judges["role"] == "Judge No.3", "role"] = "J3"
judges.loc[judges["role"] == "Judge No.4", "role"] = "J4"
judges.loc[judges["role"] == "Judge No.5", "role"] = "J5"
judges.loc[judges["role"] == "Judge No.6", "role"] = "J6"
judges.loc[judges["role"] == "Judge No.7", "role"] = "J7"
judges.loc[judges["role"] == "Judge No.8", "role"] = "J8"
judges.loc[judges["role"] == "Judge No.9", "role"] = "J9"

# %%
# creo il df facendo una inner join tra aspects e performances:
print("performances.shape:",performances.shape)
print("aspects.shape:",aspects.shape)
df = aspects.merge(performances,
                   how='inner',
                   on='performance_id')
# Out:
# performances.shape: (1726, 7)
# aspects.shape: (23932, 5)

# %%
# aggiungo tutta la tabella scores
print("df.shape:",df.shape)
print("scores.shape:",scores.shape)
df = df.merge(scores,
              how='inner',
              on='aspect_id')
# Out:
# df.shape: (23932, 11)
# scores.shape: (214531, 3)

# %%
print("df.shape:",df.shape)
# Out:
# df.shape: (214531, 13)

# %%
# aggiungo nomi e nazionalità dei giudici
print("df.shape:",df.shape)
print("judges.shape:",judges.shape)
df = df.merge(judges,
              how='inner',
              left_on=['competition','program','judge'],
              right_on=['competition','program','role'])
# Out:
# df.shape: (214531, 13)
# judges.shape: (1368, 5)

# %%
print("df.shape:",df.shape)
# Out:
# df.shape: (214531, 16)

# %%
df.head(1)
# Out:
#     aspect_id performance_id     section  aspect_desc  aspect_final_score  \
# 0  00034b9414     b639d77459  components  Transitions                9.07
#
#                                       competition               program  \
# 0  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
#
#         athlete_name athlete_nation  rank  total_deductions judge  \
# 0  Evgenia MEDVEDEVA            RUS     1               0.0    J1
#
#    judge_score judge_nation role   judge_name
# 0          9.0          ISU   J1  Agita ABELE

# %%
# elimino le colonne non più necessarie
df.drop('judge', axis=1, inplace=True)
df.drop('role', axis=1, inplace=True)

# %%
df.head(1)
# Out:
#     aspect_id performance_id     section  aspect_desc  aspect_final_score  \
# 0  00034b9414     b639d77459  components  Transitions                9.07
#
#                                       competition               program  \
# 0  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
#
#         athlete_name athlete_nation  rank  total_deductions  judge_score  \
# 0  Evgenia MEDVEDEVA            RUS     1               0.0          9.0
#
#   judge_nation   judge_name
# 0          ISU  Agita ABELE

# %%
# riordino le colonne in modo sensato
df = df[['competition',
         'program',
         'performance_id',
         'athlete_name',
         'athlete_nation',
         'rank',
         'total_deductions',
         'aspect_id',
         'aspect_desc',
         'section',
         'aspect_final_score',
         'judge_name',
         'judge_nation',
         'judge_score'
        ]]

# %%
df.head(50)
# Out:
#                                        competition               program  \
# 0   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 1   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 2   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 3   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 4   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 5   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 6   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 7   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 8   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 9   ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 10  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 11  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 12  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 13  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 14  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 15  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 16  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 17  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 18  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 19  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 20  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 21  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 22  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 23  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 24  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 25  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 26  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 27  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 28  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 29  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 30  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 31  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 32  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 33  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 34  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 35  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 36  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 37  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 38  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 39  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 40  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 41  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 42  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 43  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 44  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 45  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 46  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 47  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 48  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
# 49  ISU European Figure Skating Championships 2017  LADIES SHORT PROGRAM
#
#    performance_id       athlete_name athlete_nation  rank  total_deductions  \
# 0      b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 1      b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 2      b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 3      b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 4      b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 5      b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 6      b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 7      b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 8      b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 9      b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 10     b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 11     b639d77459  Evgenia MEDVEDEVA            RUS     1               0.0
# 12     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 13     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 14     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 15     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 16     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 17     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 18     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 19     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 20     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 21     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 22     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 23     4764e4873e      Natasha MCKAY            GBR    24               0.0
# 24     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 25     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 26     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 27     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 28     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 29     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 30     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 31     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 32     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 33     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 34     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 35     877e5c34bb    Anna POGORILAYA            RUS     2               0.0
# 36     53868b204a      Kerstin FRANK            AUT    17               0.0
# 37     53868b204a      Kerstin FRANK            AUT    17               0.0
# 38     53868b204a      Kerstin FRANK            AUT    17               0.0
# 39     53868b204a      Kerstin FRANK            AUT    17               0.0
# 40     53868b204a      Kerstin FRANK            AUT    17               0.0
# 41     53868b204a      Kerstin FRANK            AUT    17               0.0
# 42     53868b204a      Kerstin FRANK            AUT    17               0.0
# 43     53868b204a      Kerstin FRANK            AUT    17               0.0
# 44     53868b204a      Kerstin FRANK            AUT    17               0.0
# 45     53868b204a      Kerstin FRANK            AUT    17               0.0
# 46     53868b204a      Kerstin FRANK            AUT    17               0.0
# 47     53868b204a      Kerstin FRANK            AUT    17               0.0
# 48     da4b091d04   Carolina KOSTNER            ITA     3               0.0
# 49     da4b091d04   Carolina KOSTNER            ITA     3               0.0
#
#      aspect_id                  aspect_desc     section  aspect_final_score  \
# 0   00034b9414                  Transitions  components                9.07
# 1   0127af74a7               Skating Skills  components                9.14
# 2   38bda018f5                          3Lo    elements                7.21
# 3   50366b5d60                        3F+3T    elements               12.16
# 4   6e36e62b05                       CCoSp4    elements                4.50
# 5   8f7180d180                           2A    elements                4.63
# 6   9158f70d60                  Composition  components                9.21
# 7   9d6f320ec5  Interpretation of the Music  components                9.36
# 8   a85b51a8e7                  Performance  components                9.36
# 9   c07f5eb3da                        FCSp4    elements                4.20
# 10  c470fc1115                         LSp4    elements                3.70
# 11  f3446fba3f                        StSq4    elements                5.60
# 12  002472182a                        FSSp4    elements                3.21
# 13  06cd6d1696  Interpretation of the Music  components                5.54
# 14  0a85228215                        StSq3    elements                3.80
# 15  190fbefa7e                           2A    elements                2.73
# 16  1fac54c76e                  Performance  components                5.50
# 17  3a9f3c8e88               Skating Skills  components                5.21
# 18  4fe8aea380                  Composition  components                5.25
# 19  5e6e1022e4                       3Lo+2T    elements                7.00
# 20  6c94dcbb68                         CSp3    elements                2.37
# 21  76e48de619                       CCoSp3    elements                3.36
# 22  a195144536                          3S<    elements                2.30
# 23  a74f3add32                  Transitions  components                5.00
# 24  01bd47859b                          3Lo    elements                6.41
# 25  123e30211e                  Composition  components                8.54
# 26  273d80fc13                           2A    elements                4.20
# 27  42462a01eb               Skating Skills  components                8.61
# 28  6ce010991d                       3Lz+3T    elements               11.70
# 29  87257a19fa                       CCoSp4    elements                4.36
# 30  90a554ff3c  Interpretation of the Music  components                8.75
# 31  ac3d87748e                  Performance  components                8.79
# 32  b11b5cae6d                        FCSp4    elements                4.13
# 33  e1f98bd09b                  Transitions  components                8.43
# 34  e48e689678                        StSq4    elements                5.40
# 35  f716565ca9                         LSp4    elements                3.70
# 36  01cfdd01de                       CCoSp4    elements                4.00
# 37  0d5c9cf486                         LSp4    elements                2.70
# 38  34be6ef298                        3T+2T    elements                6.50
# 39  48fb57cc3c                  Transitions  components                5.21
# 40  760692144c                           3S    elements                5.14
# 41  96ccffd2c0  Interpretation of the Music  components                5.57
# 42  ad01320db2                  Performance  components                5.79
# 43  c18c1c70e2                        StSq3    elements                3.37
# 44  d2c785939a                        FCSp4    elements                3.27
# 45  e06dd3ed7b                           2A    elements                4.06
# 46  ed8f495eb6                  Composition  components                5.57
# 47  fa6344aea5               Skating Skills  components                5.89
# 48  01e4a91010               Skating Skills  components                8.89
# 49  087cbb2685                           2A    elements                4.27
#
#      judge_name judge_nation  judge_score
# 0   Agita ABELE          ISU         9.00
# 1   Agita ABELE          ISU         9.25
# 2   Agita ABELE          ISU         3.00
# 3   Agita ABELE          ISU         3.00
# 4   Agita ABELE          ISU         2.00
# 5   Agita ABELE          ISU         2.00
# 6   Agita ABELE          ISU         9.25
# 7   Agita ABELE          ISU         9.50
# 8   Agita ABELE          ISU         9.50
# 9   Agita ABELE          ISU         2.00
# 10  Agita ABELE          ISU         2.00
# 11  Agita ABELE          ISU         3.00
# 12  Agita ABELE          ISU         0.00
# 13  Agita ABELE          ISU         5.25
# 14  Agita ABELE          ISU         1.00
# 15  Agita ABELE          ISU        -2.00
# 16  Agita ABELE          ISU         5.25
# 17  Agita ABELE          ISU         5.00
# 18  Agita ABELE          ISU         5.00
# 19  Agita ABELE          ISU         1.00
# 20  Agita ABELE          ISU         1.00
# 21  Agita ABELE          ISU         1.00
# 22  Agita ABELE          ISU        -2.00
# 23  Agita ABELE          ISU         4.75
# 24  Agita ABELE          ISU         1.00
# 25  Agita ABELE          ISU         8.75
# 26  Agita ABELE          ISU         2.00
# 27  Agita ABELE          ISU         9.00
# 28  Agita ABELE          ISU         2.00
# 29  Agita ABELE          ISU         2.00
# 30  Agita ABELE          ISU         9.25
# 31  Agita ABELE          ISU         9.00
# 32  Agita ABELE          ISU         2.00
# 33  Agita ABELE          ISU         8.50
# 34  Agita ABELE          ISU         3.00
# 35  Agita ABELE          ISU         1.00
# 36  Agita ABELE          ISU         1.00
# 37  Agita ABELE          ISU         0.00
# 38  Agita ABELE          ISU         2.00
# 39  Agita ABELE          ISU         5.75
# 40  Agita ABELE          ISU         1.00
# 41  Agita ABELE          ISU         6.25
# 42  Agita ABELE          ISU         6.50
# 43  Agita ABELE          ISU         1.00
# 44  Agita ABELE          ISU         1.00
# 45  Agita ABELE          ISU         1.00
# 46  Agita ABELE          ISU         6.25
# 47  Agita ABELE          ISU         6.25
# 48  Agita ABELE          ISU         9.25
# 49  Agita ABELE          ISU         1.00
